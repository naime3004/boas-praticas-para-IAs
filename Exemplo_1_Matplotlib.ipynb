# %% [markdown]
# <a href="https://colab.research.google.com/github/naime3004/boas-praticas-para-IAs/blob/main/Exemplo_1_Matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib

# %%
from sklearn.datasets import make_regression
x, y = make_regression(n_samples=200, n_features=1, noise=30)
import matplotlib.pyplot as plt

# %%
plt.scatter(x,y)
plt.show()
